# %%
#####  Abdullah Al Mahmud , Week 6 Exercise Visualization  ######
#################################################################
###Basic (using diabetes.data):
## Regenerate a ton of figures (> 50) showing data with at least 3+ features at a time,
##leveraging things like:
##○ multiple plots on the same figure
##○ multiple plots on the same axes
##○ colours, markers, sizes, shapes, hue, etc...
##○ 3D visualizations
##○ use any library you want!

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import os
os.chdir("D:\\ConcordiaBigdata\\IntroductionBigDataTechnology\\02112019")
os.getcwd()
# Out:
# 'D:\\ConcordiaBigdata\\IntroductionBigDataTechnology\\02112019'

# %%
data = pd.read_csv('diabetes.data',sep='\t')
data.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
# AGE    442 non-null int64
# SEX    442 non-null int64
# BMI    442 non-null float64
# BP     442 non-null float64
# S1     442 non-null int64
# S2     442 non-null float64
# S3     442 non-null float64
# S4     442 non-null float64
# S5     442 non-null float64
# S6     442 non-null int64
# Y      442 non-null int64
# dtypes: float64(6), int64(5)
# memory usage: 38.1 KB

# %%
data.describe()
# Out:
#               AGE         SEX         BMI          BP          S1          S2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                S3          S4          S5          S6           Y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# ...

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000D3D9CC3AC8>,
# ...
#       dtype=object)

# %%
sns.pairplot(data)

# %%
data.boxplot()

# %%
cor = data.corr(method ='pearson')
sns.heatmap(cor)

# %%
data.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
f,ax1 = plt.subplots(figsize =(20,5))
sns.pointplot(x='AGE',y='BMI',data=data,color='lime',alpha=0.8)
sns.pointplot(x='AGE',y='BP',data=data,color='red',alpha=0.8)
sns.pointplot(x='AGE',y='S1',data=data,color='blue',alpha=0.8)
sns.pointplot(x='AGE',y='S2',data=data,color='green',alpha=0.8)
sns.pointplot(x='AGE',y='S3',data=data,color='violet',alpha=0.8)
sns.pointplot(x='AGE',y='S4',data=data,color='indigo',alpha=0.8)
sns.pointplot(x='AGE',y='S5',data=data,color='orange',alpha=0.8)
sns.pointplot(x='AGE',y='S6',data=data,color='black',alpha=0.8)
sns.pointplot(x='AGE',y='Y',data=data,color='royalblue',alpha=0.8)

# %%
data.plot(kind='density', subplots=True, layout=(4,3), sharex=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000D3DA721EC8>,
# ...
#       dtype=object)

# %%
data.plot(kind='box', subplots=True, layout=(4,3), sharex=False, sharey=False)
# Out:
# AGE        AxesSubplot(0.125,0.71587;0.227941x0.16413)
# SEX     AxesSubplot(0.398529,0.71587;0.227941x0.16413)
# BMI     AxesSubplot(0.672059,0.71587;0.227941x0.16413)
# BP        AxesSubplot(0.125,0.518913;0.227941x0.16413)
# S1     AxesSubplot(0.398529,0.518913;0.227941x0.16413)
# S2     AxesSubplot(0.672059,0.518913;0.227941x0.16413)
# S3        AxesSubplot(0.125,0.321957;0.227941x0.16413)
# S4     AxesSubplot(0.398529,0.321957;0.227941x0.16413)
# S5     AxesSubplot(0.672059,0.321957;0.227941x0.16413)
# S6           AxesSubplot(0.125,0.125;0.227941x0.16413)
# Y         AxesSubplot(0.398529,0.125;0.227941x0.16413)
# dtype: object

# %%
sns.swarmplot(x='AGE',y='BP',data=data)

# %%
from mpl_toolkits import mplot3d
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = data['AGE']
ys = data['BMI']
zs = data['BP']
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('AGE')
ax.set_ylabel('BMI')
ax.set_zlabel('BP')
# Out:
# Text(0.5, 0, 'BP')

# %%
##Advanced:
##From all your figures, tell me the greatest one for interpreting your data, and justify why
##by explicitly comparing it to some other figures! Write which figure, why and your
##comparison on your README.MD file.
print ("Among these plots, I think pair plots (sns.pairplot(data)) is the best to see all the fields. It gives us a quick and easily understandable view of the data distribution. It also gives us if there are correlations between different fields.")
# Out:
# Among these plots, I think pair plots (sns.pairplot(data)) is the best to see all the fields. It gives us a quick and easily understandable view of the data distribution. It also gives us if there are correlations between different fields.

# %%
##Reach (using train_titanic.csv):
##Create two box plots to compare the fares of male and female with whiskers indicating
##significant differences between the two groups.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
#%matplotlib inline

plt.style.use('bmh')
# %matplotlib inline
import os
os.chdir("D:\\ConcordiaBigdata\\IntroductionBigDataTechnology\\02112019")
os.getcwd()

data = pd.read_csv("train_titanic.csv")
#data = pd.read_csv("titanic.csv")
print (data.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print (data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# None

# %%
print (data.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data1 = data.dropna()
print (data1.head())
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
print (data1.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
df = data1[data1.Fare <300]
print (df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   181.000000  181.000000  181.000000  181.000000  181.000000
# mean    452.563536    0.668508    1.193370   35.676354    0.469613
# std     246.943454    0.472055    0.517644   15.730437    0.645854
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.000000    0.000000    1.000000   24.000000    0.000000
# 50%     454.000000    1.000000    1.000000   36.000000    0.000000
# 75%     663.000000    1.000000    1.000000   48.000000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  181.000000  181.000000
# mean     0.475138   73.890792
# std      0.756961   61.491733
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   56.929200
# 75%      1.000000   90.000000
# max      4.000000  263.000000

# %%
df1=data.dropna(subset=['Fare'])
print (df1.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print (df1[df1.Fare>300].count())
# Out:
# PassengerId    3
# Survived       3
# Pclass         3
# Name           3
# Sex            3
# Age            3
# SibSp          3
# Parch          3
# Ticket         3
# Fare           3
# Cabin          2
# Embarked       3
# dtype: int64

# %%
# box plot of sex for Fare
plt.figure(figsize=(12, 8))
#sns.boxplot(x='Sex', y='Fare', hue='Survived', data=df1)
plt.title("Fare vs Sex",fontsize=12)
sns.boxplot(x='Sex', y='Fare', data=df1)
#plt.show()

# %%
plt.figure(figsize=(12, 8))
ax = sns.boxplot(x="Sex", y="Fare",hue='Survived', data=df1)
#ax = sns.stripplot(x="Sex", y="Fare",data=df1, hue='Survived', jitter=True, edgecolor="gray")
plt.title("Fare vs survival between Male and Female",fontsize=12)
#plt.show()
# Out:
# Text(0.5, 1.0, 'Fare vs survival between Male and Female')
